# %%
import os
os.environ["GROQ_API_KEY"] = "your_real_groq_api_key_here"
# verify
print(os.getenv("GROQ_API_KEY") is not None)
# Out:
# True

# %%
from dotenv import load_dotenv
import os
load_dotenv()               # reads .env into os.environ
print(os.getenv("GROQ_API_KEY"))
# Out:
# your_real_groq_api_key_here

# %%
from langchain_groq import ChatGroq

# %%
llm =  ChatGroq(model = "deepseek-r1-distill-llama-70b")

# %%
llm.invoke("hi")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 llm.invoke("hi")
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:382, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     368 @override
#     369 def invoke(
#     370     self,
#    (...)    375     **kwargs: Any,
#     376 ) -> AIMessage:
#     377     config = ensure_config(config)
#     378     return cast(
#     379         "AIMessage",
#     380         cast(
#     381             "ChatGeneration",
# --> 382             self.generate_prompt(
#     383                 [self._convert_input(input)],
#     384                 stop=stop,
#     385                 callbacks=config.get("callbacks"),
#     386                 tags=config.get("tags"),
#     387                 metadata=config.get("metadata"),
#     388                 run_name=config.get("run_name"),
#     389                 run_id=config.pop("run_id", None),
#     390                 **kwargs,
#     391             ).generations[0][0],
#     392         ).message,
#     393     )
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1091, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1082 @override
#    1083 def generate_prompt(
#    1084     self,
#    (...)   1088     **kwargs: Any,
#    1089 ) -> LLMResult:
#    1090     prompt_messages = [p.to_messages() for p in prompts]
# -> 1091     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:906, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     903 for i, m in enumerate(input_messages):
#     904     try:
#     905         results.append(
# --> 906             self._generate_with_cache(
#     907                 m,
#     908                 stop=stop,
#     909                 run_manager=run_managers[i] if run_managers else None,
#     910                 **kwargs,
#     911             )
#     912         )
#     913     except BaseException as e:
#     914         if run_managers:
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1195, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1193     result = generate_from_stream(iter(chunks))
#    1194 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1195     result = self._generate(
#    1196         messages, stop=stop, run_manager=run_manager, **kwargs
#    1197     )
#    1198 else:
#    1199     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\langchain_groq\chat_models.py:544, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     539 message_dicts, params = self._create_message_dicts(messages, stop)
#     540 params = {
#     541     **params,
#     542     **kwargs,
#     543 }
# --> 544 response = self.client.create(messages=message_dicts, **params)
#     545 return self._create_chat_result(response, params)
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\groq\resources\chat\completions.py:464, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     244 def create(
#     245     self,
#     246     *,
#    (...)    303     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     304 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     305     """
#     306     Creates a model response for the given chat conversation.
#     307
#    (...)    462       timeout: Override the client-level default timeout for this request, in seconds
#     463     """
# --> 464     return self._post(
#     465         "/openai/v1/chat/completions",
#     466         body=maybe_transform(
#     467             {
#     468                 "messages": messages,
#     469                 "model": model,
#     470                 "citation_options": citation_options,
#     471                 "compound_custom": compound_custom,
#     472                 "disable_tool_validation": disable_tool_validation,
#     473                 "documents": documents,
#     474                 "exclude_domains": exclude_domains,
#     475                 "frequency_penalty": frequency_penalty,
#     476                 "function_call": function_call,
#     477                 "functions": functions,
#     478                 "include_domains": include_domains,
#     479                 "include_reasoning": include_reasoning,
#     480                 "logit_bias": logit_bias,
#     481                 "logprobs": logprobs,
#     482                 "max_completion_tokens": max_completion_tokens,
#     483                 "max_tokens": max_tokens,
#     484                 "metadata": metadata,
#     485                 "n": n,
#     486                 "parallel_tool_calls": parallel_tool_calls,
#     487                 "presence_penalty": presence_penalty,
#     488                 "reasoning_effort": reasoning_effort,
#     489                 "reasoning_format": reasoning_format,
#     490                 "response_format": response_format,
#     491                 "search_settings": search_settings,
#     492                 "seed": seed,
#     493                 "service_tier": service_tier,
#     494                 "stop": stop,
#     495                 "store": store,
#     496                 "stream": stream,
#     497                 "temperature": temperature,
#     498                 "tool_choice": tool_choice,
#     499                 "tools": tools,
#     500                 "top_logprobs": top_logprobs,
#     501                 "top_p": top_p,
#     502                 "user": user,
#     503             },
#     504             completion_create_params.CompletionCreateParams,
#     505         ),
#     506         options=make_request_options(
#     507             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     508         ),
#     509         cast_to=ChatCompletion,
#     510         stream=stream or False,
#     511         stream_cls=Stream[ChatCompletionChunk],
#     512     )
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\groq\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\AI_Learning\Agentic_AI_Project\.venv\Lib\site-packages\groq\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}
